# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/police_deaths_USA_v6.csv")
df
# Out:
#                  Rank                    Name   Age End_Of_Watch Day_Of_Week  \
# 0           Constable           Darius Quimby   NaN   1791-01-03      Monday
# 1             Sheriff      Cornelius Hogeboom  53.0   1791-10-22    Saturday
# 2      Deputy Sheriff             Isaac Smith   NaN   1792-05-17    Thursday
# 3             Marshal          Robert Forsyth  40.0   1794-01-11    Saturday
# 4      Deputy Sheriff          Robert Berwick   NaN   1797-06-29    Thursday
# ...               ...                     ...   ...          ...         ...
# 25618  Police Officer           Donald Sahota  52.0   2022-01-29    Saturday
# 25619  Deputy Sheriff             Ned P. Byrd  48.0   2022-08-11    Thursday
# 25620      K9 Officer   Ryan Patrick Copeland  33.0   2015-11-23      Monday
# 25621      K9 Officer  Timothy James Brackeen  38.0   2016-09-12      Monday
# 25622      K9 Officer   Jordan Harris Sheldon  32.0   2019-05-04    Saturday
#
#                        Cause  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25623 entries, 0 to 25622
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          25623 non-null  object
#  1   Name          25623 non-null  object
#  2   Age           22946 non-null  float64
#  3   End_Of_Watch  25623 non-null  object
#  4   Day_Of_Week   25623 non-null  object
#  5   Cause         25622 non-null  object
#  6   Department    25623 non-null  object
#  7   State         25623 non-null  object
#  8   Tour          17417 non-null  object
#  9   Badge         7477 non-null   object
#  10  Weapon        16263 non-null  object
#  11  Offender      13803 non-null  object
#  12  Summary       25623 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 2.5+ MB

# %%
df['Cause'].unique()

#missingno.matrix(df_titulos)
#plt.show()
# Out:
# array(['Stabbed', 'Gunfire', 'Duty related illness', 'Assault', 'Fall',
#        'Drowned', 'Structure collapse', 'Fire', 'Gunfire (Inadvertent)',
#        'Explosion', 'Vehicular assault', 'Animal related', 'Heart attack',
#        'Weather/Natural disaster', 'Accidental', 'Hypothermia',
#        'Heatstroke', 'Train accident', 'Struck by streetcar',
#        'Struck by train', 'Bomb', 'Poisoned', 'Electrocuted',
#        'Boating accident', 'Bicycle accident', 'Automobile crash',
#        'Struck by vehicle', nan, 'Exposure to toxins', 'Motorcycle crash',
#        'Vehicle pursuit', 'Unidentified', 'Training accident',
#        'Aircraft accident', 'Terrorist attack', '9/11 related illness',
#        'COVID19'], dtype=object)

# %%
df['Department'].unique()
# Out:
# array(["Albany County Constable's Office, New York",
#        "Columbia County Sheriff's Office, New York",
#        "Westchester County Sheriff's Department, New York", ...,
#        "Pima County Constable's Office, Arizona",
#        'Vancouver Police Department, Washington',
#        'McFarland Police Department, Wisconsin'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([  nan,   53.,   40.,   45.,   52.,   74.,   20.,   48.,   46.,
#          33.,   27.,   60.,   24.,   56.,   61.,   43.,   83.,   66.,
#          25.,   31.,   34.,   70.,   21.,   44.,   37.,   36.,   38.,
#          30.,   22.,   47.,   41.,   35.,   42.,   18.,   17.,   32.,
#          29.,   50.,   28.,   49.,   39.,   26.,   51.,   23.,   55.,
#          54.,   19.,   63.,   67.,   65.,   71.,   73.,   59.,   62.,
#          57.,   58.,   69.,   68.,   64.,   75.,   81.,   77.,   89.,
#          78.,   72.,   76.,   79.,   84.,   80.,   96., 1661.,   92.,
#          82.])

# %%
df['Tour'].unique()
# Out:
# array([nan, '2 years', '4 years, 4 months', '1 year, 4 months',
#        '10 months', '4 months', '6 months', '25 years', '1 week',
#        '12 years', '40 years', '1 year', '3 years', '13 years', '1 day',
#        '1 month, 3 weeks', '2 weeks', '2 months', '1 month', '3 months',
#        '3 days', '7 years', '3 years, 5 months', '9 years', '5 months',
#        '4 days', '8 years', '2 years, 6 months', '9 months', '5 years',
#        '4 years', '2 months, 1 week', '2 months, 4 weeks', '10 years',
#        '6 years', '1 month, 1 week', '1 year, 6 months', '14 years',
#        '11 years', '22 years', '1 month, 2 weeks', '7 months', '34 years',
#        '3 weeks', '8 months', '2 years, 9 months', '15 years',
#        '6 years, 1 month', '1 year, 8 months', '2 days',
#        '1 year, 7 months', '2 years, 1 month', '11 months',
#        '12 years, 6 months', '2 months, 3 weeks', '1 year, 2 months',
#        '3 years, 6 months', '3 months, 3 weeks', '4 years, 10 months',
# ...

# %%
df['Tour'] = df['Tour'].fillna("0 tiempo")
df['Tour'].unique()
# Out:
# array(['0 tiempo', '2 years', '4 years, 4 months', '1 year, 4 months',
#        '10 months', '4 months', '6 months', '25 years', '1 week',
#        '12 years', '40 years', '1 year', '3 years', '13 years', '1 day',
#        '1 month, 3 weeks', '2 weeks', '2 months', '1 month', '3 months',
#        '3 days', '7 years', '3 years, 5 months', '9 years', '5 months',
#        '4 days', '8 years', '2 years, 6 months', '9 months', '5 years',
#        '4 years', '2 months, 1 week', '2 months, 4 weeks', '10 years',
#        '6 years', '1 month, 1 week', '1 year, 6 months', '14 years',
#        '11 years', '22 years', '1 month, 2 weeks', '7 months', '34 years',
#        '3 weeks', '8 months', '2 years, 9 months', '15 years',
#        '6 years, 1 month', '1 year, 8 months', '2 days',
#        '1 year, 7 months', '2 years, 1 month', '11 months',
#        '12 years, 6 months', '2 months, 3 weeks', '1 year, 2 months',
#        '3 years, 6 months', '3 months, 3 weeks', '4 years, 10 months',
# ...

# %%
df['Tour']=df['Tour'].str.replace(' 0','')
df['Tour']=df['Tour'].str.replace(' ','--')
df['Tour'].unique()
# Out:
# array(['0--tiempo', '2--years', '4--years,--4--months',
#        '1--year,--4--months', '10--months', '4--months', '6--months',
#        '25--years', '1--week', '12--years', '40--years', '1--year',
#        '3--years', '13--years', '1--day', '1--month,--3--weeks',
#        '2--weeks', '2--months', '1--month', '3--months', '3--days',
#        '7--years', '3--years,--5--months', '9--years', '5--months',
#        '4--days', '8--years', '2--years,--6--months', '9--months',
#        '5--years', '4--years', '2--months,--1--week',
#        '2--months,--4--weeks', '10--years', '6--years',
#        '1--month,--1--week', '1--year,--6--months', '14--years',
#        '11--years', '22--years', '1--month,--2--weeks', '7--months',
#        '34--years', '3--weeks', '8--months', '2--years,--9--months',
#        '15--years', '6--years,--1--month', '1--year,--8--months',
#        '2--days', '1--year,--7--months', '2--years,--1--month',
# ...
